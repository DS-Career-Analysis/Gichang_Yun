# %%
import pandas as pd

saramin_df = pd.read_csv('saramin_df.csv', encoding='utf-8')
saramin_df
# Out:
#              회사명          직무  \
# 0     (주)이음인터렉티브  데이터 사이언티스트
# 1         데이콘(주)  데이터 사이언티스트
# 2       (주)위키드스톰  데이터 사이언티스트
# 3          (주)카비  데이터 사이언티스트
# 4      (주)핀커스코리아  데이터 사이언티스트
# ...          ...         ...
# 2374   (주)케이티넥스알    데이터 엔지니어
# 2375   롯데헬스케어(주)    데이터 엔지니어
# 2376    (주)제이슨그룹    데이터 엔지니어
# 2377    (주)오투플러스    데이터 엔지니어
# 2378    주식회사 마이너    데이터 엔지니어
#
#                                                      링크  \
# 0     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 3     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 4     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# ...                                                 ...
# 2374  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2375  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2376  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# ...
